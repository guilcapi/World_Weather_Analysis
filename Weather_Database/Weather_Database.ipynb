# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-90, 90, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 776

# %%
import requests
from datetime import datetime
import os, sys
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=468ec1b105aceb856a141b25cb0d9dff

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
#for i in range(len(cities)):
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | marsh harbour
# Processing Record 4 of Set 1 | sagua la grande
# Processing Record 5 of Set 1 | nanortalik
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | key largo
# Processing Record 13 of Set 1 | clinton
# Processing Record 14 of Set 1 | abu samrah
# Processing Record 15 of Set 1 | kankan
# Processing Record 16 of Set 1 | richards bay
# Processing Record 17 of Set 1 | hambantota
# Processing Record 18 of Set 1 | gobabis
# Processing Record 19 of Set 1 | pangnirtung
# Processing Record 20 of Set 1 | gurupi
# Processing Record 21 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 22 of Set 1 | lagoa
# Processing Record 23 of Set 1 | marabba
# Processing Record 24 of Set 1 | hargeysa
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | kalmunai
# Processing Record 27 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | neuquen
# Processing Record 31 of Set 1 | torbay
# Processing Record 32 of Set 1 | wattegama
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | zlatarica
# City not found. Skipping...
# Processing Record 35 of Set 1 | povenets
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | larsnes
# Processing Record 39 of Set 1 | kudahuvadhoo
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | gamba
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | la rioja
# Processing Record 44 of Set 1 | buchanan
# Processing Record 45 of Set 1 | nushki
# Processing Record 46 of Set 1 | brazzaville
# Processing Record 47 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | saint-augustin
# Processing Record 1 of Set 2 | mwinilunga
# Processing Record 2 of Set 2 | impfondo
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | moissala
# Processing Record 6 of Set 2 | atar
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | porto novo
# Processing Record 9 of Set 2 | olinda
# Processing Record 10 of Set 2 | moche
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | beni
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | atasu
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | tatishchevo
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | de aar
# Processing Record 19 of Set 2 | lucapa
# Processing Record 20 of Set 2 | frantiskovy lazne
# Processing Record 21 of Set 2 | punto fijo
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | ostrovnoy
# Processing Record 24 of Set 2 | gombe
# Processing Record 25 of Set 2 | chicama
# Processing Record 26 of Set 2 | kokomo
# Processing Record 27 of Set 2 | santa rosa
# Processing Record 28 of Set 2 | phalodi
# Processing Record 29 of Set 2 | aden
# Processing Record 30 of Set 2 | leh
# Processing Record 31 of Set 2 | taltal
# Processing Record 32 of Set 2 | cascais
# Processing Record 33 of Set 2 | tazovskiy
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | shuyskoye
# Processing Record 36 of Set 2 | lavumisa
# Processing Record 37 of Set 2 | halberstadt
# Processing Record 38 of Set 2 | rocha
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | geraldton
# Processing Record 44 of Set 2 | montepuez
# Processing Record 45 of Set 2 | margate
# Processing Record 46 of Set 2 | monforte de lemos
# Processing Record 47 of Set 2 | pontes e lacerda
# Processing Record 48 of Set 2 | ust-koksa
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | mehamn
# Processing Record 1 of Set 3 | antofagasta
# Processing Record 2 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 3 | bilma
# Processing Record 4 of Set 3 | husainabad
# Processing Record 5 of Set 3 | muisne
# Processing Record 6 of Set 3 | viedma
# Processing Record 7 of Set 3 | novyye burasy
# Processing Record 8 of Set 3 | oyonnax
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | itarema
# Processing Record 11 of Set 3 | praia
# Processing Record 12 of Set 3 | el carmen de bolivar
# Processing Record 13 of Set 3 | maragogi
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | marzuq
# Processing Record 16 of Set 3 | bandarbeyla
# Processing Record 17 of Set 3 | ponta delgada
# Processing Record 18 of Set 3 | michigan city
# Processing Record 19 of Set 3 | soubre
# Processing Record 20 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | polunochnoye
# Processing Record 23 of Set 3 | coria
# Processing Record 24 of Set 3 | yarada
# Processing Record 25 of Set 3 | acajutla
# Processing Record 26 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | ajdabiya
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | yacuiba
# Processing Record 31 of Set 3 | sommerda
# Processing Record 32 of Set 3 | peniche
# Processing Record 33 of Set 3 | yangambi
# Processing Record 34 of Set 3 | santa pola
# Processing Record 35 of Set 3 | praia da vitoria
# Processing Record 36 of Set 3 | olafsvik
# Processing Record 37 of Set 3 | punta arenas
# Processing Record 38 of Set 3 | tiznit
# Processing Record 39 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 3 | korla
# Processing Record 41 of Set 3 | riviere-au-renard
# Processing Record 42 of Set 3 | pucallpa
# Processing Record 43 of Set 3 | daule
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | maldonado
# Processing Record 47 of Set 3 | los llanos de aridane
# Processing Record 48 of Set 3 | tasiilaq
# Processing Record 49 of Set 3 | cape town
# Processing Record 50 of Set 3 | souillac
# Processing Record 1 of Set 4 | ambatondrazaka
# Processing Record 2 of Set 4 | usakos
# Processing Record 3 of Set 4 | waren
# Processing Record 4 of Set 4 | sayat
# Processing Record 5 of Set 4 | leku
# Processing Record 6 of Set 4 | beloha
# Processing Record 7 of Set 4 | haverfordwest
# Processing Record 8 of Set 4 | taoudenni
# Processing Record 9 of Set 4 | bonavista
# Processing Record 10 of Set 4 | chapais
# Processing Record 11 of Set 4 | ndola
# Processing Record 12 of Set 4 | vardo
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | corinto
# Processing Record 15 of Set 4 | butterworth
# Processing Record 16 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 17 of Set 4 | the valley
# Processing Record 18 of Set 4 | yevlax
# Processing Record 19 of Set 4 | caxias
# Processing Record 20 of Set 4 | comodoro rivadavia
# Processing Record 21 of Set 4 | santa lucia
# Processing Record 22 of Set 4 | kamenka
# Processing Record 23 of Set 4 | adrar
# Processing Record 24 of Set 4 | muhos
# Processing Record 25 of Set 4 | rio de janeiro
# Processing Record 26 of Set 4 | upernavik
# Processing Record 27 of Set 4 | kattivakkam
# Processing Record 28 of Set 4 | lebu
# Processing Record 29 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 30 of Set 4 | xuddur
# Processing Record 31 of Set 4 | henties bay
# Processing Record 32 of Set 4 | muli
# Processing Record 33 of Set 4 | brae
# Processing Record 34 of Set 4 | malpura
# Processing Record 35 of Set 4 | dahod
# Processing Record 36 of Set 4 | coquimbo
# Processing Record 37 of Set 4 | molochnoye
# Processing Record 38 of Set 4 | cayenne
# Processing Record 39 of Set 4 | demba
# Processing Record 40 of Set 4 | pakwach
# City not found. Skipping...
# Processing Record 41 of Set 4 | nyagan
# Processing Record 42 of Set 4 | faya
# Processing Record 43 of Set 4 | paramonga
# Processing Record 44 of Set 4 | palampur
# Processing Record 45 of Set 4 | yining
# Processing Record 46 of Set 4 | quatre cocos
# Processing Record 47 of Set 4 | portel
# Processing Record 48 of Set 4 | odienne
# Processing Record 49 of Set 4 | havelock
# Processing Record 50 of Set 4 | raja jang
# Processing Record 1 of Set 5 | port-gentil
# Processing Record 2 of Set 5 | minsk
# Processing Record 3 of Set 5 | vila franca do campo
# Processing Record 4 of Set 5 | pangody
# Processing Record 5 of Set 5 | ponta pora
# Processing Record 6 of Set 5 | awbari
# Processing Record 7 of Set 5 | tromso
# Processing Record 8 of Set 5 | leshukonskoye
# Processing Record 9 of Set 5 | kataysk
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | padang
# Processing Record 12 of Set 5 | nouadhibou
# Processing Record 13 of Set 5 | zelenoborskiy
# Processing Record 14 of Set 5 | bayir
# Processing Record 15 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 5 | thunder bay
# Processing Record 17 of Set 5 | karabuk
# Processing Record 18 of Set 5 | nicoya
# Processing Record 19 of Set 5 | gualeguay
# Processing Record 20 of Set 5 | sabha
# Processing Record 21 of Set 5 | izhma
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 24 of Set 5 | cambridge
# Processing Record 25 of Set 5 | saint george
# Processing Record 26 of Set 5 | constitucion
# Processing Record 27 of Set 5 | mogadishu
# Processing Record 28 of Set 5 | port blair
# Processing Record 29 of Set 5 | bubaque
# Processing Record 30 of Set 5 | kirkkonummi
# Processing Record 31 of Set 5 | hamilton
# Processing Record 32 of Set 5 | vvedenskoye
# Processing Record 33 of Set 5 | cururupu
# Processing Record 34 of Set 5 | constantine
# Processing Record 35 of Set 5 | namibe
# Processing Record 36 of Set 5 | oranjemund
# Processing Record 37 of Set 5 | zambezi
# Processing Record 38 of Set 5 | sompeta
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | yar-sale
# Processing Record 41 of Set 5 | teguldet
# Processing Record 42 of Set 5 | canutama
# Processing Record 43 of Set 5 | gat
# Processing Record 44 of Set 5 | raudeberg
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | umm lajj
# Processing Record 47 of Set 5 | victoria
# Processing Record 48 of Set 5 | icatu
# Processing Record 49 of Set 5 | tshikapa
# Processing Record 50 of Set 5 | santa maria
# Processing Record 1 of Set 6 | khudumelapye
# Processing Record 2 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 6 | castro
# Processing Record 4 of Set 6 | ballitoville
# Processing Record 5 of Set 6 | jaciara
# Processing Record 6 of Set 6 | klaksvik
# Processing Record 7 of Set 6 | sinnamary
# Processing Record 8 of Set 6 | bansi
# Processing Record 9 of Set 6 | vallenar
# Processing Record 10 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 6 | japura
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | gallneukirchen
# Processing Record 14 of Set 6 | gazalkent
# Processing Record 15 of Set 6 | san ramon de la nueva oran
# Processing Record 16 of Set 6 | mahibadhoo
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | nuuk
# Processing Record 19 of Set 6 | dmitriyevka
# Processing Record 20 of Set 6 | macusani
# Processing Record 21 of Set 6 | riyadh
# Processing Record 22 of Set 6 | port hawkesbury
# Processing Record 23 of Set 6 | kolokani
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | mocuba
# Processing Record 26 of Set 6 | belaya
# Processing Record 27 of Set 6 | mana
# Processing Record 28 of Set 6 | okitipupa
# Processing Record 29 of Set 6 | irtyshskiy
# Processing Record 30 of Set 6 | port elizabeth
# Processing Record 31 of Set 6 | dudinka
# Processing Record 32 of Set 6 | zhezkazgan
# Processing Record 33 of Set 6 | kirkenaer
# Processing Record 34 of Set 6 | lasa
# Processing Record 35 of Set 6 | melo
# Processing Record 36 of Set 6 | semirom
# Processing Record 37 of Set 6 | mga
# Processing Record 38 of Set 6 | barinas
# Processing Record 39 of Set 6 | likhoy
# Processing Record 40 of Set 6 | metz
# Processing Record 41 of Set 6 | gurkovo
# Processing Record 42 of Set 6 | maputo
# Processing Record 43 of Set 6 | sur
# Processing Record 44 of Set 6 | chik
# Processing Record 45 of Set 6 | quarai
# Processing Record 46 of Set 6 | marquette
# Processing Record 47 of Set 6 | mbacke
# City not found. Skipping...
# Processing Record 48 of Set 6 | state college
# Processing Record 49 of Set 6 | tucuman
# Processing Record 50 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 1 of Set 7 | halifax
# Processing Record 2 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 3 of Set 7 | alindao
# Processing Record 4 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 7 | saint anthony
# Processing Record 6 of Set 7 | bereda
# Processing Record 7 of Set 7 | bandar-e lengeh
# Processing Record 8 of Set 7 | grand gaube
# Processing Record 9 of Set 7 | belyy yar
# Processing Record 10 of Set 7 | uyuni
# Processing Record 11 of Set 7 | pitimbu
# Processing Record 12 of Set 7 | lubango
# Processing Record 13 of Set 7 | la asuncion
# Processing Record 14 of Set 7 | masaka
# Processing Record 15 of Set 7 | malartic
# Processing Record 16 of Set 7 | kruisfontein
# Processing Record 17 of Set 7 | soyo
# Processing Record 18 of Set 7 | borba
# Processing Record 19 of Set 7 | honningsvag
# Processing Record 20 of Set 7 | kankakee
# Processing Record 21 of Set 7 | dunwoody
# Processing Record 22 of Set 7 | longyearbyen
# Processing Record 23 of Set 7 | clermont
# Processing Record 24 of Set 7 | san rafael
# Processing Record 25 of Set 7 | kharitonovo
# Processing Record 26 of Set 7 | hobyo
# Processing Record 27 of Set 7 | haripur
# Processing Record 28 of Set 7 | puri
# Processing Record 29 of Set 7 | ewo
# Processing Record 30 of Set 7 | opuwo
# Processing Record 31 of Set 7 | starodub
# Processing Record 32 of Set 7 | san cristobal
# Processing Record 33 of Set 7 | voznesenye
# Processing Record 34 of Set 7 | newnan
# Processing Record 35 of Set 7 | anloga
# Processing Record 36 of Set 7 | lamu
# Processing Record 37 of Set 7 | rio gallegos
# Processing Record 38 of Set 7 | thana
# Processing Record 39 of Set 7 | crotone
# Processing Record 40 of Set 7 | bardsir
# Processing Record 41 of Set 7 | road town
# Processing Record 42 of Set 7 | saint-georges
# Processing Record 43 of Set 7 | tena
# Processing Record 44 of Set 7 | gryazi
# Processing Record 45 of Set 7 | ambilobe
# Processing Record 46 of Set 7 | avila
# Processing Record 47 of Set 7 | zharkent
# Processing Record 48 of Set 7 | spas-demensk
# Processing Record 49 of Set 7 | rakiv lis
# Processing Record 50 of Set 7 | homa bay
# Processing Record 1 of Set 8 | berlevag
# Processing Record 2 of Set 8 | karasuk
# Processing Record 3 of Set 8 | togur
# Processing Record 4 of Set 8 | copiapo
# Processing Record 5 of Set 8 | genthin
# Processing Record 6 of Set 8 | meulaboh
# Processing Record 7 of Set 8 | bangolo
# Processing Record 8 of Set 8 | plettenberg bay
# Processing Record 9 of Set 8 | bathsheba
# Processing Record 10 of Set 8 | calabozo
# Processing Record 11 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 8 | vestmanna
# Processing Record 13 of Set 8 | cah ab
# City not found. Skipping...
# Processing Record 14 of Set 8 | tazmalt
# Processing Record 15 of Set 8 | talcher
# Processing Record 16 of Set 8 | bonga
# Processing Record 17 of Set 8 | carutapera
# Processing Record 18 of Set 8 | algiers
# Processing Record 19 of Set 8 | juba
# Processing Record 20 of Set 8 | rusape
# Processing Record 21 of Set 8 | akbarpur
# Processing Record 22 of Set 8 | camopi
# Processing Record 23 of Set 8 | forio
# Processing Record 24 of Set 8 | qaqortoq
# Processing Record 25 of Set 8 | destin
# Processing Record 26 of Set 8 | khorixas
# Processing Record 27 of Set 8 | shakiso
# Processing Record 28 of Set 8 | dawlatabad
# Processing Record 29 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 8 | sioux lookout
# Processing Record 31 of Set 8 | laguna
# Processing Record 32 of Set 8 | dwarka
# Processing Record 33 of Set 8 | graneros
# Processing Record 34 of Set 8 | dergachi
# Processing Record 35 of Set 8 | hofn
# Processing Record 36 of Set 8 | jhanjharpur
# Processing Record 37 of Set 8 | clarence town
# Processing Record 38 of Set 8 | siuna
# Processing Record 39 of Set 8 | rawson
# Processing Record 40 of Set 8 | niamey
# Processing Record 41 of Set 8 | luis correia
# Processing Record 42 of Set 8 | touros
# Processing Record 43 of Set 8 | jardim
# Processing Record 44 of Set 8 | brandon
# Processing Record 45 of Set 8 | bokoro
# Processing Record 46 of Set 8 | oshawa
# Processing Record 47 of Set 8 | fomboni
# Processing Record 48 of Set 8 | mombasa
# Processing Record 49 of Set 8 | usinsk
# Processing Record 50 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 1 of Set 9 | buritis
# Processing Record 2 of Set 9 | encruzilhada do sul
# Processing Record 3 of Set 9 | nasirabad
# Processing Record 4 of Set 9 | belmonte
# Processing Record 5 of Set 9 | billere
# Processing Record 6 of Set 9 | moroni
# Processing Record 7 of Set 9 | rozivka
# Processing Record 8 of Set 9 | alekseyevka
# Processing Record 9 of Set 9 | tomaszow lubelski
# Processing Record 10 of Set 9 | husavik
# Processing Record 11 of Set 9 | tucuma
# Processing Record 12 of Set 9 | oussouye
# Processing Record 13 of Set 9 | carndonagh
# Processing Record 14 of Set 9 | tocopilla
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | mbini
# Processing Record 17 of Set 9 | imeni babushkina
# Processing Record 18 of Set 9 | tabou
# Processing Record 19 of Set 9 | chapada dos guimaraes
# Processing Record 20 of Set 9 | baghdad
# Processing Record 21 of Set 9 | qasigiannguit
# Processing Record 22 of Set 9 | raga
# Processing Record 23 of Set 9 | bonthe
# Processing Record 24 of Set 9 | iquique
# Processing Record 25 of Set 9 | ilhabela
# Processing Record 26 of Set 9 | oktyabrskoye
# Processing Record 27 of Set 9 | puerto narino
# Processing Record 28 of Set 9 | abu kamal
# Processing Record 29 of Set 9 | great yarmouth
# Processing Record 30 of Set 9 | goundam
# Processing Record 31 of Set 9 | aksu
# Processing Record 32 of Set 9 | biltine
# Processing Record 33 of Set 9 | ornskoldsvik
# Processing Record 34 of Set 9 | shelburne
# Processing Record 35 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 36 of Set 9 | gambela
# Processing Record 37 of Set 9 | montepulciano
# Processing Record 38 of Set 9 | quelimane
# Processing Record 39 of Set 9 | cabo rojo
# Processing Record 40 of Set 9 | mayumba
# Processing Record 41 of Set 9 | dakar
# Processing Record 42 of Set 9 | grindavik
# Processing Record 43 of Set 9 | salvador
# Processing Record 44 of Set 9 | arys
# Processing Record 45 of Set 9 | sokolo
# Processing Record 46 of Set 9 | marawi
# Processing Record 47 of Set 9 | necochea
# Processing Record 48 of Set 9 | nkhotakota
# Processing Record 49 of Set 9 | santa isabel do rio negro
# Processing Record 50 of Set 9 | nampula
# Processing Record 1 of Set 10 | bombay
# Processing Record 2 of Set 10 | tandalti
# Processing Record 3 of Set 10 | aksay
# Processing Record 4 of Set 10 | kashi
# Processing Record 5 of Set 10 | filingue
# Processing Record 6 of Set 10 | pindiga
# Processing Record 7 of Set 10 | mahon
# Processing Record 8 of Set 10 | puerto leguizamo
# Processing Record 9 of Set 10 | tessalit
# Processing Record 10 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 10 | alta floresta
# Processing Record 12 of Set 10 | deda
# Processing Record 13 of Set 10 | lincoln
# Processing Record 14 of Set 10 | robertsport
# Processing Record 15 of Set 10 | pascagoula
# Processing Record 16 of Set 10 | duverge
# Processing Record 17 of Set 10 | vilhena
# Processing Record 18 of Set 10 | nioki
# Processing Record 19 of Set 10 | goderich
# Processing Record 20 of Set 10 | ilebo
# Processing Record 21 of Set 10 | gualeguaychu
# Processing Record 22 of Set 10 | tutoia
# Processing Record 23 of Set 10 | rio grande
# Processing Record 24 of Set 10 | hurghada
# Processing Record 25 of Set 10 | natal
# Processing Record 26 of Set 10 | cap malheureux
# Processing Record 27 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 28 of Set 10 | kayerkan
# Processing Record 29 of Set 10 | kita
# Processing Record 30 of Set 10 | talara
# Processing Record 31 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 10 | zelenogorskiy
# Processing Record 33 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 10 | monrovia
# Processing Record 35 of Set 10 | george
# Processing Record 36 of Set 10 | yaounde
# Processing Record 37 of Set 10 | chamba
# Processing Record 38 of Set 10 | cuamba
# Processing Record 39 of Set 10 | port antonio
# Processing Record 40 of Set 10 | guiratinga
# Processing Record 41 of Set 10 | karasjok
# Processing Record 42 of Set 10 | birao
# Processing Record 43 of Set 10 | asyut
# Processing Record 44 of Set 10 | bahia de caraquez
# Processing Record 45 of Set 10 | poros
# Processing Record 46 of Set 10 | kidal
# Processing Record 47 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 10 | saint-pierre
# Processing Record 49 of Set 10 | zadar
# Processing Record 50 of Set 10 | makambako
# Processing Record 1 of Set 11 | isabela
# Processing Record 2 of Set 11 | pauini
# Processing Record 3 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 11 | medvedok
# Processing Record 5 of Set 11 | ichchapuram
# Processing Record 6 of Set 11 | kapuskasing
# Processing Record 7 of Set 11 | arlit
# Processing Record 8 of Set 11 | kostomuksha
# Processing Record 9 of Set 11 | jalu
# Processing Record 10 of Set 11 | itaituba
# Processing Record 11 of Set 11 | sisimiut
# Processing Record 12 of Set 11 | shieli
# Processing Record 13 of Set 11 | gorkovskoye
# City not found. Skipping...
# Processing Record 14 of Set 11 | san juan
# Processing Record 15 of Set 11 | parana
# Processing Record 16 of Set 11 | sao joao da barra
# Processing Record 17 of Set 11 | torbat-e jam
# Processing Record 18 of Set 11 | vila velha
# Processing Record 19 of Set 11 | chipinge
# Processing Record 20 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 11 | binga
# Processing Record 22 of Set 11 | panaba
# Processing Record 23 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 24 of Set 11 | rajapur
# Processing Record 25 of Set 11 | sao jose da coroa grande
# Processing Record 26 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 11 | riohacha
# Processing Record 28 of Set 11 | pishin
# Processing Record 29 of Set 11 | terbuny
# Processing Record 30 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 31 of Set 11 | sayabec
# City not found. Skipping...
# Processing Record 32 of Set 11 | tera
# Processing Record 33 of Set 11 | liverpool
# Processing Record 34 of Set 11 | saint-francois
# Processing Record 35 of Set 11 | jumla
# Processing Record 36 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 38 of Set 11 | komatipoort
# Processing Record 39 of Set 11 | faridabad
# Processing Record 40 of Set 11 | ashtabula
# Processing Record 41 of Set 11 | guaimaca
# Processing Record 42 of Set 11 | jeremoabo
# Processing Record 43 of Set 11 | zivinice
# Processing Record 44 of Set 11 | sorland
# Processing Record 45 of Set 11 | normandin
# Processing Record 46 of Set 11 | malanje
# Processing Record 47 of Set 11 | ochamchira
# Processing Record 48 of Set 11 | omboue
# Processing Record 49 of Set 11 | cabedelo
# Processing Record 50 of Set 11 | wilmington
# Processing Record 1 of Set 12 | murgab
# Processing Record 2 of Set 12 | brewster
# Processing Record 3 of Set 12 | dhidhdhoo
# Processing Record 4 of Set 12 | uruacu
# Processing Record 5 of Set 12 | lixourion
# Processing Record 6 of Set 12 | malatya
# Processing Record 7 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 12 | patti
# Processing Record 9 of Set 12 | dalbandin
# Processing Record 10 of Set 12 | ust-tsilma
# Processing Record 11 of Set 12 | balkhash
# Processing Record 12 of Set 12 | krasnoarmeysk
# Processing Record 13 of Set 12 | gweta
# Processing Record 14 of Set 12 | boa vista
# Processing Record 15 of Set 12 | bossangoa
# Processing Record 16 of Set 12 | sao luis
# Processing Record 17 of Set 12 | kabalo
# Processing Record 18 of Set 12 | boysun
# Processing Record 19 of Set 12 | vangaindrano
# Processing Record 20 of Set 12 | trincomalee
# Processing Record 21 of Set 12 | teeli
# Processing Record 22 of Set 12 | mizan teferi
# Processing Record 23 of Set 12 | guliston
# Processing Record 24 of Set 12 | mahajanga
# Processing Record 25 of Set 12 | villarrica
# Processing Record 26 of Set 12 | urumqi
# Processing Record 27 of Set 12 | george town
# Processing Record 28 of Set 12 | chiredzi
# Processing Record 29 of Set 12 | gubbi
# Processing Record 30 of Set 12 | rosario
# Processing Record 31 of Set 12 | luena
# Processing Record 32 of Set 12 | zarakes
# City not found. Skipping...
# Processing Record 33 of Set 12 | camacha
# Processing Record 34 of Set 12 | matara
# Processing Record 35 of Set 12 | aljezur
# Processing Record 36 of Set 12 | porto walter
# Processing Record 37 of Set 12 | guerande
# Processing Record 38 of Set 12 | nova olinda do norte
# Processing Record 39 of Set 12 | mitsamiouli
# Processing Record 40 of Set 12 | newberry
# Processing Record 41 of Set 12 | zamora
# Processing Record 42 of Set 12 | wamba
# Processing Record 43 of Set 12 | campbellton
# Processing Record 44 of Set 12 | bebedouro
# Processing Record 45 of Set 12 | thompson
# Processing Record 46 of Set 12 | presidencia roque saenz pena
# Processing Record 47 of Set 12 | seminole
# Processing Record 48 of Set 12 | mao
# Processing Record 49 of Set 12 | pinega
# Processing Record 50 of Set 12 | marystown
# Processing Record 1 of Set 13 | andenes
# Processing Record 2 of Set 13 | akodia
# Processing Record 3 of Set 13 | paramirim
# Processing Record 4 of Set 13 | igarka
# Processing Record 5 of Set 13 | la baule-escoublac
# Processing Record 6 of Set 13 | banepa
# Processing Record 7 of Set 13 | kautokeino
# Processing Record 8 of Set 13 | keita
# Processing Record 9 of Set 13 | diapaga
# Processing Record 10 of Set 13 | asfi
# Processing Record 11 of Set 13 | pachmarhi
# Processing Record 12 of Set 13 | rijeka
# Processing Record 13 of Set 13 | douentza
# Processing Record 14 of Set 13 | troitsko-pechorsk
# Processing Record 15 of Set 13 | manga
# Processing Record 16 of Set 13 | orsk
# Processing Record 17 of Set 13 | shihezi
# Processing Record 18 of Set 13 | abu dhabi
# Processing Record 19 of Set 13 | elizabeth city
# Processing Record 20 of Set 13 | banatski karlovac
# Processing Record 21 of Set 13 | karabanovo
# Processing Record 22 of Set 13 | baharampur
# Processing Record 23 of Set 13 | inongo
# Processing Record 24 of Set 13 | saint-ambroise
# Processing Record 25 of Set 13 | guadix
# Processing Record 26 of Set 13 | fundong
# Processing Record 27 of Set 13 | stromness
# Processing Record 28 of Set 13 | mantua
# Processing Record 29 of Set 13 | pocone
# Processing Record 30 of Set 13 | kuytun
# Processing Record 31 of Set 13 | necocli
# Processing Record 32 of Set 13 | bouca
# Processing Record 33 of Set 13 | valday
# Processing Record 34 of Set 13 | glyadyanskoye
# Processing Record 35 of Set 13 | tergnier
# Processing Record 36 of Set 13 | tirano
# Processing Record 37 of Set 13 | kaba
# Processing Record 38 of Set 13 | bougouni
# Processing Record 39 of Set 13 | ballina
# Processing Record 40 of Set 13 | olavarria
# Processing Record 41 of Set 13 | polyarnyy
# Processing Record 42 of Set 13 | aswan
# Processing Record 43 of Set 13 | libertador general san martin
# Processing Record 44 of Set 13 | bahia honda
# Processing Record 45 of Set 13 | malakal
# Processing Record 46 of Set 13 | bardiyah
# Processing Record 47 of Set 13 | agirish
# Processing Record 48 of Set 13 | havoysund
# Processing Record 49 of Set 13 | sanquhar
# Processing Record 50 of Set 13 | storforshei
# Processing Record 1 of Set 14 | diffa
# Processing Record 2 of Set 14 | barraute
# Processing Record 3 of Set 14 | odweyne
# Processing Record 4 of Set 14 | bafra
# Processing Record 5 of Set 14 | bushehr
# Processing Record 6 of Set 14 | ubinskoye
# Processing Record 7 of Set 14 | corn island
# Processing Record 8 of Set 14 | la palma
# Processing Record 9 of Set 14 | klerksdorp
# Processing Record 10 of Set 14 | urubicha
# Processing Record 11 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 14 | gonen
# Processing Record 13 of Set 14 | stantsionno-oyashinskiy
# Processing Record 14 of Set 14 | muzhi
# Processing Record 15 of Set 14 | rio bueno
# Processing Record 16 of Set 14 | sitio novo do tocantins
# Processing Record 17 of Set 14 | conakry
# Processing Record 18 of Set 14 | mangai
# Processing Record 19 of Set 14 | agadir
# Processing Record 20 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 14 | hattiesburg
# Processing Record 22 of Set 14 | bud
# Processing Record 23 of Set 14 | tasco
# Processing Record 24 of Set 14 | severnyy
# Processing Record 25 of Set 14 | kars
# Processing Record 26 of Set 14 | roald
# Processing Record 27 of Set 14 | filadelfia
# Processing Record 28 of Set 14 | luanda
# Processing Record 29 of Set 14 | sergiyevsk
# Processing Record 30 of Set 14 | belebey
# Processing Record 31 of Set 14 | divnomorskoye
# Processing Record 32 of Set 14 | saginaw
# Processing Record 33 of Set 14 | marsa matruh
# Processing Record 34 of Set 14 | vizinga
# Processing Record 35 of Set 14 | severodvinsk
# Processing Record 36 of Set 14 | saint-paul
# Processing Record 37 of Set 14 | kirkwall
# Processing Record 38 of Set 14 | camana
# Processing Record 39 of Set 14 | kumluca
# Processing Record 40 of Set 14 | turukhansk
# Processing Record 41 of Set 14 | clearwater
# Processing Record 42 of Set 14 | huarmey
# Processing Record 43 of Set 14 | manono
# Processing Record 44 of Set 14 | mus
# Processing Record 45 of Set 14 | karla
# Processing Record 46 of Set 14 | xghajra
# City not found. Skipping...
# Processing Record 47 of Set 14 | kalofer
# Processing Record 48 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 14 | leninaul
# Processing Record 50 of Set 14 | portsmouth
# Processing Record 1 of Set 15 | campo verde
# Processing Record 2 of Set 15 | guayaramerin
# Processing Record 3 of Set 15 | sept-iles
# Processing Record 4 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 15 | limon
# Processing Record 6 of Set 15 | soure
# Processing Record 7 of Set 15 | mvomero
# Processing Record 8 of Set 15 | katete
# Processing Record 9 of Set 15 | vigrestad
# Processing Record 10 of Set 15 | agadez
# Processing Record 11 of Set 15 | loiza
# Processing Record 12 of Set 15 | taraclia
# Processing Record 13 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 14 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 15 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 15 | orasac
# Processing Record 17 of Set 15 | diu
# Processing Record 18 of Set 15 | skibbereen
# Processing Record 19 of Set 15 | porciuncula
# Processing Record 20 of Set 15 | valparaiso
# Processing Record 21 of Set 15 | yanam
# Processing Record 22 of Set 15 | maralal
# Processing Record 23 of Set 15 | tamale
# Processing Record 24 of Set 15 | saint-denis
# Processing Record 25 of Set 15 | westport
# Processing Record 26 of Set 15 | latehar
# Processing Record 27 of Set 15 | mouzakion
# City not found. Skipping...
# Processing Record 28 of Set 15 | akdepe
# Processing Record 29 of Set 15 | lumeje
# Processing Record 30 of Set 15 | sturgeon falls
# Processing Record 31 of Set 15 | nsukka
# Processing Record 32 of Set 15 | lilongwe
# Processing Record 33 of Set 15 | turtas
# Processing Record 34 of Set 15 | emborion
# Processing Record 35 of Set 15 | lekoni
# Processing Record 36 of Set 15 | yokadouma
# Processing Record 37 of Set 15 | puerto guzman
# Processing Record 38 of Set 15 | kragero
# Processing Record 39 of Set 15 | paamiut
# Processing Record 40 of Set 15 | lagos
# Processing Record 41 of Set 15 | camacupa
# Processing Record 42 of Set 15 | manoharpur
# Processing Record 43 of Set 15 | sistranda
# Processing Record 44 of Set 15 | arklow
# Processing Record 45 of Set 15 | sao miguel do araguaia
# Processing Record 46 of Set 15 | kaka
# Processing Record 47 of Set 15 | keflavik
# Processing Record 48 of Set 15 | velsk
# Processing Record 49 of Set 15 | palora
# Processing Record 50 of Set 15 | windhoek
# Processing Record 1 of Set 16 | booue
# Processing Record 2 of Set 16 | kochki
# Processing Record 3 of Set 16 | bluefield
# Processing Record 4 of Set 16 | fulton
# Processing Record 5 of Set 16 | morant bay
# Processing Record 6 of Set 16 | nema
# Processing Record 7 of Set 16 | vicuna
# Processing Record 8 of Set 16 | rey bouba
# Processing Record 9 of Set 16 | sinop
# Processing Record 10 of Set 16 | carros
# Processing Record 11 of Set 16 | san luis
# Processing Record 12 of Set 16 | maniitsoq
# Processing Record 13 of Set 16 | buraydah
# Processing Record 14 of Set 16 | weiz
# Processing Record 15 of Set 16 | konevo
# Processing Record 16 of Set 16 | workington
# Processing Record 17 of Set 16 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 18 of Set 16 | salinas
# Processing Record 19 of Set 16 | ghorawal
# Processing Record 20 of Set 16 | uvat
# Processing Record 21 of Set 16 | floro
# Processing Record 22 of Set 16 | hun
# Processing Record 23 of Set 16 | gayeri
# Processing Record 24 of Set 16 | oban
# Processing Record 25 of Set 16 | abonnema
# Processing Record 26 of Set 16 | eyl
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bredasdorp -34.53  20.04     64.40        88           9        8.05
# 1    Marsh Harbour  26.54 -77.06     81.28        79          10       11.39
# 2  Sagua La Grande  22.81 -80.08     87.80        66          75       13.87
# 3       Nanortalik  60.14 -45.24     29.64        87           0       26.78
# 4          Ushuaia -54.80 -68.30     57.20        58          75       11.41
#
#   Country Current Description
# 0      ZA           clear sky
# 1      BS           clear sky
# 2      CU       broken clouds
# 3      GL           clear sky
# 4      AR          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bredasdorp      ZA -34.53  20.04     64.40        88           9
# 1    Marsh Harbour      BS  26.54 -77.06     81.28        79          10
# 2  Sagua La Grande      CU  22.81 -80.08     87.80        66          75
# 3       Nanortalik      GL  60.14 -45.24     29.64        87           0
# 4          Ushuaia      AR -54.80 -68.30     57.20        58          75
#
#    Wind Speed Current Description
# 0        8.05           clear sky
# 1       11.39           clear sky
# 2       13.87       broken clouds
# 3       26.78           clear sky
# 4       11.41          light rain

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
